# %% [markdown]
# # SP2 - Working with data from Boligportalen

# %%
import pandas as pd 
pd.read_csv('/Users/mathiaspoulsen/Python-projects/docker_notebooks/notebooks/my_work/boligportalen.csv')
# Out:
#     Unnamed: 0       type  price  square_meter                       location  \
# 0            0  Lejlighed  12255            86    København, Else Alfelts Vej
# 1            1    Værelse   4500            25         København, Italiensvej
# 2            2  Lejlighed  13495            95  København, Ørestads Boulevard
# 3            3  Lejlighed  13495            96  København, Ørestads Boulevard
# 4            4  Lejlighed  13594            96  København, Ørestads Boulevard
# ..         ...        ...    ...           ...                            ...
# 67          67  Lejlighed  17495           146      Rødovre, Nørregårdsbakken
# 68          68  Lejlighed  13800            88     Søborg, Buddinge Hovedgade
# 69          69  Lejlighed  24500           191           Hellerup, Gersonsvej
# 70          70   Rækkehus  16995           150      Rødovre, Nørregårdsbakken
# 71          71  Lejlighed   6995            39           Vanløse, Godthåbsvej
#
# ...
